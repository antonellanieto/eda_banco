# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('trans_bank.csv')
df
# Out:
#        Forecast_Cd       Forecast_Name       fecha     mth  dia_sem  \
# 0              602      ACCESS BANKING    1/1/2012  201201        1
# 1              400                 ATM    1/1/2012  201201        1
# 2              601  CONNECTION BANKING    1/1/2012  201201        1
# 3              201       HOLA OPERADOR    1/1/2012  201201        1
# 4              202                 IVR    1/1/2012  201201        1
# ...            ...                 ...         ...     ...      ...
# 39789          202                 IVR  12/31/2022  202212        7
# 39790          500              MOBILE  12/31/2022  202212        7
# 39791          100          SUCURSALES  12/31/2022  202212        7
# 39792          302                 TAS  12/31/2022  202212        7
# 39793          701                  TS  12/31/2022  202212        7
#
#       dia_sem_txt  cierre_tj  Cant_Trx  flag_tj_vto  flag_tv_vto  flag_tm_vto  \
# 0             DOM        0.0     60971          NaN          NaN          NaN
# 1             DOM        0.0     14642          NaN          NaN          NaN
# 2             DOM        0.0         0          NaN          NaN          NaN
# 3             DOM        0.0         0          NaN          NaN          NaN
# 4             DOM        0.0         0          NaN          NaN          NaN
# ...           ...        ...       ...          ...          ...          ...
# 39789         SAB        NaN         0          0.0          0.0          0.0
# 39790         SAB        NaN    329834          0.0          0.0          0.0
# 39791         SAB        NaN         0          0.0          0.0          0.0
# 39792         SAB        NaN      7153          0.0          0.0          0.0
# 39793         SAB        NaN         0          0.0          0.0          0.0
#
#        flag_tj_cierre  flag_tv_cierre  flag_tm_cierre
# 0                 NaN             NaN             NaN
# 1                 NaN             NaN             NaN
# 2                 NaN             NaN             NaN
# 3                 NaN             NaN             NaN
# 4                 NaN             NaN             NaN
# ...               ...             ...             ...
# 39789             0.0             0.0             0.0
# 39790             0.0             0.0             0.0
# 39791             0.0             0.0             0.0
# 39792             0.0             0.0             0.0
# 39793             0.0             0.0             0.0
#
# [39794 rows x 14 columns]

# %%
#Fecha a datetime type object
df['fecha'] = pd.to_datetime(df['fecha'])

# %%
#Filtro por dos canales. IVR y Mobile
mobile_and_ivr_df = df[df['Forecast_Cd'].isin([202, 500])]
mobile_and_ivr_df
# Out:
#        Forecast_Cd Forecast_Name      fecha     mth  dia_sem dia_sem_txt  \
# 4              202           IVR 2012-01-01  201201        1         DOM
# 5              500        MOBILE 2012-01-01  201201        1         DOM
# 14             202           IVR 2012-01-02  201201        2         LUN
# 15             500        MOBILE 2012-01-02  201201        2         LUN
# 24             202           IVR 2012-01-03  201201        3         MAR
# ...            ...           ...        ...     ...      ...         ...
# 39772          500        MOBILE 2022-12-29  202212        5         JUE
# 39780          202           IVR 2022-12-30  202212        6         VIE
# 39781          500        MOBILE 2022-12-30  202212        6         VIE
# 39789          202           IVR 2022-12-31  202212        7         SAB
# 39790          500        MOBILE 2022-12-31  202212        7         SAB
#
#        cierre_tj  Cant_Trx  flag_tj_vto  flag_tv_vto  flag_tm_vto  \
# 4            0.0         0          NaN          NaN          NaN
# 5            0.0       644          NaN          NaN          NaN
# 14           0.0         0          NaN          NaN          NaN
# 15           0.0      1080          NaN          NaN          NaN
# 24           0.0     31615          NaN          NaN          NaN
# ...          ...       ...          ...          ...          ...
# 39772        NaN    423956          0.0          0.0          0.0
# 39780        NaN     10266          0.0          0.0          0.0
# 39781        NaN    676819          0.0          0.0          0.0
# 39789        NaN         0          0.0          0.0          0.0
# 39790        NaN    329834          0.0          0.0          0.0
#
#        flag_tj_cierre  flag_tv_cierre  flag_tm_cierre
# 4                 NaN             NaN             NaN
# 5                 NaN             NaN             NaN
# 14                NaN             NaN             NaN
# 15                NaN             NaN             NaN
# 24                NaN             NaN             NaN
# ...               ...             ...             ...
# 39772             1.0             1.0             1.0
# 39780             0.0             0.0             0.0
# 39781             0.0             0.0             0.0
# 39789             0.0             0.0             0.0
# 39790             0.0             0.0             0.0
#
# [8036 rows x 14 columns]

# %%
mobile_and_ivr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8036 entries, 4 to 39790
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Forecast_Cd     8036 non-null   int64
#  1   Forecast_Name   8036 non-null   object
#  2   fecha           8036 non-null   datetime64[ns]
#  3   mth             8036 non-null   int64
#  4   dia_sem         8036 non-null   int64
#  5   dia_sem_txt     8036 non-null   object
#  6   cierre_tj       5218 non-null   float64
#  7   Cant_Trx        8036 non-null   int64
#  8   flag_tj_vto     5906 non-null   float64
#  9   flag_tv_vto     5906 non-null   float64
#  10  flag_tm_vto     5906 non-null   float64
#  11  flag_tj_cierre  5906 non-null   float64
#  12  flag_tv_cierre  5906 non-null   float64
#  13  flag_tm_cierre  5906 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(4), object(2)
# memory usage: 941.7+ KB

# %%
mobile_and_ivr_df.describe()
# Out:
#        Forecast_Cd                          fecha            mth      dia_sem  \
# count  8036.000000                           8036    8036.000000  8036.000000
# mean    351.000000  2017-07-01 12:00:00.000000256  201706.447984     4.000000
# min     202.000000            2012-01-01 00:00:00  201201.000000     1.000000
# 25%     202.000000            2014-10-01 00:00:00  201410.000000     2.000000
# 50%     351.000000            2017-07-01 12:00:00  201707.000000     4.000000
# 75%     500.000000            2020-04-01 00:00:00  202004.000000     6.000000
# max     500.000000            2022-12-31 00:00:00  202212.000000     7.000000
# std     149.009272                            NaN     316.286984     2.000124
#
#          cierre_tj      Cant_Trx  flag_tj_vto  flag_tv_vto  flag_tm_vto  \
# count  5218.000000  8.036000e+03  5906.000000  5906.000000  5906.000000
# mean      0.327328  7.378282e+04     0.200135     0.133762     0.067050
# min       0.000000  0.000000e+00     0.000000     0.000000     0.000000
# 25%       0.000000  8.102000e+03     0.000000     0.000000     0.000000
# 50%       0.000000  1.555450e+04     0.000000     0.000000     0.000000
# 75%       0.000000  3.874825e+04     0.000000     0.000000     0.000000
# max       6.000000  1.646684e+06     1.000000     1.000000     1.000000
# std       0.870900  1.410127e+05     0.400135     0.340426     0.250131
#
#        flag_tj_cierre  flag_tv_cierre  flag_tm_cierre
# count     5906.000000     5906.000000     5906.000000
# mean         0.134440        0.133424        0.067728
# min          0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000
# 50%          0.000000        0.000000        0.000000
# 75%          0.000000        0.000000        0.000000
# max          1.000000        1.000000        1.000000
# std          0.341153        0.340061        0.251299

# %%
mobile_and_ivr_df.isnull().sum()
# Out:
# Forecast_Cd          0
# Forecast_Name        0
# fecha                0
# mth                  0
# dia_sem              0
# dia_sem_txt          0
# cierre_tj         2818
# Cant_Trx             0
# flag_tj_vto       2130
# flag_tv_vto       2130
# flag_tm_vto       2130
# flag_tj_cierre    2130
# flag_tv_cierre    2130
# flag_tm_cierre    2130
# dtype: int64

# %%
#Análisis univariable
mobile_and_ivr_df['Cant_Trx'].describe()
# Out:
# count    8.036000e+03
# mean     7.378282e+04
# std      1.410127e+05
# min      0.000000e+00
# 25%      8.102000e+03
# 50%      1.555450e+04
# 75%      3.874825e+04
# max      1.646684e+06
# Name: Cant_Trx, dtype: float64

# %%
plt.hist(mobile_and_ivr_df['Cant_Trx'], bins=20, edgecolor='black')
plt.xlabel('Cantidad de Transacciones')
plt.ylabel('Frecuencia')
plt.title('Distribución de la Cantidad de Transacciones')
plt.show()

# %%
df.groupby('Forecast_Name')['Cant_Trx'].sum().reset_index()
# Out:
#         Forecast_Name    Cant_Trx
# 0      ACCESS BANKING  1894325586
# 1                 ATM   261481471
# 2  CONNECTION BANKING   319113370
# 3       HOLA OPERADOR    36340674
# 4                 IVR    41113236
# 5              MOBILE   551805533
# 6                 QDB    38928259
# 7          SUCURSALES   184871893
# 8                 TAS    30022273
# 9                  TS     4546800

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Forecast_Name', y='Cant_Trx', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Nombre de Canal')
plt.ylabel('Cantidad de Transacciones')
plt.title('Exploración de Transacciones por Canal')
plt.show()
# Out:
# C:\Users\anieto\AppData\Local\Temp\ipykernel_7876\788452188.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Forecast_Name', y='Cant_Trx', data=df, palette='viridis')

# %%
mobile_and_ivr_df['año'] = mobile_and_ivr_df['fecha'].dt.year
# Out:
# C:\Users\anieto\AppData\Local\Temp\ipykernel_7876\2997464705.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mobile_and_ivr_df['año'] = mobile_and_ivr_df['fecha'].dt.year

# %%
ivr = mobile_and_ivr_df[mobile_and_ivr_df['Forecast_Name'] == 'IVR']
ivr
# Out:
#        Forecast_Cd Forecast_Name      fecha     mth  dia_sem dia_sem_txt  \
# 4              202           IVR 2012-01-01  201201        1         DOM
# 14             202           IVR 2012-01-02  201201        2         LUN
# 24             202           IVR 2012-01-03  201201        3         MAR
# 34             202           IVR 2012-01-04  201201        4         MIE
# 44             202           IVR 2012-01-05  201201        5         JUE
# ...            ...           ...        ...     ...      ...         ...
# 39753          202           IVR 2022-12-27  202212        3         MAR
# 39762          202           IVR 2022-12-28  202212        4         MIE
# 39771          202           IVR 2022-12-29  202212        5         JUE
# 39780          202           IVR 2022-12-30  202212        6         VIE
# 39789          202           IVR 2022-12-31  202212        7         SAB
#
#        cierre_tj  Cant_Trx  flag_tj_vto  flag_tv_vto  flag_tm_vto  \
# 4            0.0         0          NaN          NaN          NaN
# 14           0.0         0          NaN          NaN          NaN
# 24           0.0     31615          NaN          NaN          NaN
# 34           0.0     19401          NaN          NaN          NaN
# 44           2.0     19800          NaN          NaN          NaN
# ...          ...       ...          ...          ...          ...
# 39753        NaN     12313          0.0          0.0          0.0
# 39762        NaN     10934          0.0          0.0          0.0
# 39771        NaN     11530          0.0          0.0          0.0
# 39780        NaN     10266          0.0          0.0          0.0
# 39789        NaN         0          0.0          0.0          0.0
#
#        flag_tj_cierre  flag_tv_cierre  flag_tm_cierre
# 4                 NaN             NaN             NaN
# 14                NaN             NaN             NaN
# 24                NaN             NaN             NaN
# 34                NaN             NaN             NaN
# 44                NaN             NaN             NaN
# ...               ...             ...             ...
# 39753             0.0             0.0             0.0
# 39762             0.0             0.0             0.0
# 39771             1.0             1.0             1.0
# 39780             0.0             0.0             0.0
# 39789             0.0             0.0             0.0
#
# [4018 rows x 14 columns]

# %%
max_trx= ivr.groupby('fecha')['Cant_Trx'].sum().idxmax()
max_trx
# Out:
# Timestamp('2020-04-13 00:00:00')

# %%
min_trx= ivr.groupby('fecha')['Cant_Trx'].sum().idxmin()
min_trx
# Out:
# Timestamp('2012-01-01 00:00:00')

# %%
max_trx_day = ivr[ivr['fecha'].dt.date == max_trx.date()]

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='fecha', y='Cant_Trx', data=max_trx_day)
plt.title(f'Boxplot para el Día con Más Transacciones del Canal IVR')
plt.xlabel('Fecha')
plt.ylabel('Número de Transacciones')
plt.xticks(rotation=45)
plt.show()

# %%
mobile_and_ivr_df['year'] = pd.to_datetime(mobile_and_ivr_df['fecha'])
# Out:
# C:\Users\anieto\AppData\Local\Temp\ipykernel_18340\2321441518.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mobile_and_ivr_df['year'] = pd.to_datetime(mobile_and_ivr_df['fecha'])

# %%
#Suma por día de cantidad de transacciones
suma_por_dia = mobile_and_ivr_df.groupby('dia_sem')['Cant_Trx'].sum()
suma_por_dia
# Out:
# dia_sem
# 1    43461316
# 2    97938241
# 3    98752041
# 4    97450815
# 5    98876503
# 6    97109302
# 7    59330551
# Name: Cant_Trx, dtype: int64

# %%
#Suma por día en orden. 
#Indica que el viernes es el día con más transacciones, en segundo lugar el miércoles, tercer día es el martes, cuarto día es el jueves, quinto
# día es el sábado, sexto lugar es el domingo y en último lugar el lunes.
suma_por_dia_en_orden = suma_por_dia.sort_values(ascending=False)
suma_por_dia_en_orden
# Out:
# dia_sem
# 5    98876503
# 3    98752041
# 2    97938241
# 4    97450815
# 6    97109302
# 7    59330551
# 1    43461316
# Name: Cant_Trx, dtype: int64

# %%
suma_por_dia_en_orden.plot(kind='bar', color='skyblue')
plt.title('Suma de cantidad de transacciones por día')
plt.xlabel('Día de la semana')
plt.ylabel('Suma transacciones')
plt.show()

# %%
#Antes de la pandemia y después

# %%
antes_febrero_2020 = mobile_and_ivr_df[mobile_and_ivr_df['fecha'] < '2020-01-02']
despues_febrero_2020 = mobile_and_ivr_df[mobile_and_ivr_df['fecha'] >= '2020-01-02']

suma_antes_2020 = antes_febrero_2020['Cant_Trx'].sum()
suma_despues_2020 = despues_febrero_2020['Cant_Trx'].sum()

print(f"Suma de cantidad de transacciones antes del 01/02/2020: {suma_antes_2020}")
print(f"Suma de cantidad de transacciones después del 01/02/2020: {suma_despues_2020}")
# Out:
# Suma de cantidad de transacciones antes del 01/02/2020: 176753694
# Suma de cantidad de transacciones después del 01/02/2020: 416165075
